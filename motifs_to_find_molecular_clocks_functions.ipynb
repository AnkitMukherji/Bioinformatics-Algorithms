# %%
from ipynb.fs.full.replication_ori_functions import HammingDistance, Neighbors;

# %% [markdown]
# **Brute force algorithm for motif finding**

# %%
def MotifEnumeration(Dna, k, d):
    Patterns = set()
    strings = Dna.split()
    for i in strings:
        for j in range(len(i) - k + 1):
            k_mer = i[j:j+k]
            neighbourhood = Neighbors(k_mer, d)
            for neighbour in neighbourhood:
                found_in_all = True
                for m in strings:
                    if not any(HammingDistance(neighbour, m[n:n+k]) <= d for n in range(len(m) - k + 1)):
                        found_in_all = False
                        break
                if found_in_all:
                    Patterns.add(neighbour)
    return Patterns

# %% [markdown]
# **Entropy calculation**

# %%
import math

def entropy(strings):
    dna = strings
    num_dna = len(dna)
    entropy_cal = 0
    a, t, g, c = 0, 0, 0, 0
    for i in range(0,len(dna[0])):
        for j in dna:
            if j[i] == 'A':
                a += 1
            elif j[i] == 'T':
                t += 1
            elif j[i] == 'G':
                g += 1
            else:
                c += 1
                
        a /= num_dna
        t /= num_dna
        g /= num_dna
        c /= num_dna
        if a > 0:
            entropy_cal += -(a * math.log2(a))
        if t > 0:
            entropy_cal += -(t * math.log2(t))
        if g > 0:
            entropy_cal += -(g * math.log2(g))
        if c > 0:
            entropy_cal += -(c * math.log2(c))
        a, t, g, c = 0, 0, 0, 0
    
    return entropy_cal

# %% [markdown]
# **Solving the Median String Problem**
